# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import scipy.stats as st
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Read csv file 
cdc_df = pd.read_csv('cdc.codes/cdc.csv')
full_data_2017 = pd.read_csv('cdc.codes/2017_code_data.csv')
full_data_2017
adult_data_2017 = pd.read_csv('cdc.codes/samadult.csv')
adult_data_2017
# Out:
#        FPX  FMX    HHX  INTV_QRT  WTIA_SA  WTFA_SA  SEX  HISPAN_I  R_MARITL  \
# 0        1    1      3         1   5829.3     5044    2        12         4
# 1        1    1      9         1   2752.4     3770    1        12         7
# 2        2    1     11         1  14902.0    17305    1        12         1
# 3        1    1     15         1   8531.8     7383    2        12         5
# 4        1    1     18         1   5477.2     8314    1         0         1
# ...    ...  ...    ...       ...      ...      ...  ...       ...       ...
# 26737    2    1  58880         4   7030.2     6082    2        12         1
# 26738    1    1  58881         4   6261.6     5557    2        12         4
# 26739    1    1  58882         4   7818.1     7603    2        12         1
# 26740    1    1  58883         4   8691.9     7833    1        12         1
# 26741    1    1  58884         4   8942.5     7937    2        12         1
#
#        MRACRPI2  ...  MBO_PRO1  YTQU_YG1  YTQ_BTY1  YTQ_MDY1  YTQU_TA1  \
# 0             1  ...         2         2       NaN       NaN         2
# 1             1  ...         2         2       NaN       NaN         2
# 2             1  ...         2         2       NaN       NaN         2
# 3             1  ...         2         1       1.0       1.0         1
# 4             1  ...         2         1       1.0       1.0         2
# ...         ...  ...       ...       ...       ...       ...       ...
# 26737         1  ...         2         2       NaN       NaN         2
# 26738         1  ...         2         2       NaN       NaN         2
# 26739         2  ...         2         2       NaN       NaN         2
# 26740         1  ...         2         2       NaN       NaN         2
# 26741         1  ...         1         2       NaN       NaN         2
#
#        YTQ_BTT1  YTQ_MDT1  YTQU_QG1  YTQ_BTQ1  YTQ_MDQ1
# 0           NaN       NaN         2       NaN       NaN
# 1           NaN       NaN         2       NaN       NaN
# 2           NaN       NaN         2       NaN       NaN
# 3           1.0       2.0         2       NaN       NaN
# 4           NaN       NaN         2       NaN       NaN
# ...         ...       ...       ...       ...       ...
# 26737       NaN       NaN         2       NaN       NaN
# 26738       NaN       NaN         2       NaN       NaN
# 26739       NaN       NaN         2       NaN       NaN
# 26740       NaN       NaN         2       NaN       NaN
# 26741       NaN       NaN         2       NaN       NaN
#
# [26742 rows x 702 columns]

# %%
# Reorganize the columns
cdc_df = cdc_df[['Code', 'Description', 'Category']]
cdc_df
# Out:
#           Code                                        Description  \
# 0       URBRRL             Geography (urban vs suburban vs rural)
# 1       REGION                      US Geographic Region (SE, NW)
# 2        SEX_A                                                Sex
# 3       HISP_A                                 Hispanic ethnicity
# 4   HISPALLP_A               Hispanic and other ethnicity (mixed)
# ..         ...                                                ...
# 69  MODFREQW_A       moderate physical activity (Y/N) / frequency
# 70  VIGFREQW_A       vigorous physical activity (Y/N) / frequency
# 71  PA18_05R_A  met 2018 physical activity guidelines = 150+ m...
# 72   SLPREST_A  sleep quality ("over past 30 days, how often d...
# 73    SLPFLL_A  sleep quality ("over past 30 days, how often d...
#
#                                   Category
# 0                             Demographics
# 1                             Demographics
# 2                             Demographics
# 3                             Demographics
# 4                             Demographics
# ..                                     ...
# 69  Lifestyle / Chronic Disease Indicators
# 70  Lifestyle / Chronic Disease Indicators
# 71  Lifestyle / Chronic Disease Indicators
# 72  Lifestyle / Chronic Disease Indicators
# 73  Lifestyle / Chronic Disease Indicators
#
# [74 rows x 3 columns]

# %%
# Removing spaces in column names
adult_data_2017.columns = adult_data_2017.columns.to_series().apply(lambda x:x.strip())

# %%
# Selecting the columns we need and adding them to a dataframe
filtered_data_2017 = adult_data_2017 [["AWEBUSE","REGION", "SEX", "HISPAN_I","RACERPI2",
                              "R_MARITL", "HYPEV", "CHLEV", "CHDEV",
                              "EPHEV", "AASMEV", "CANEV", "DIBEV1",
                              "DIBTYPE", "EPILEP1", "ARTH1", "HRAIDNOW",
                              "AVISION", "AHSTATYR", "PAINLMT", "FLWALK",
                              "ALCHRONR", "SMKSTAT2", "MODFREQW", "ALCSTAT",
                              "AHCPLROU", "AWORPAY", "ADNLONG2", "AHCSYR1",
                              "AHERNOY2", "AHCHYR", "ASRGYR", "AMDLONGR",
                              "AEXCHNG", "ASICPUSE", "ASISIM", "ASISIF",
                              "ASISLPFL", "MBO_SPR1", "AFLHCA17"]]
filtered_data_2017.head()
# Out:
#    AWEBUSE  REGION  SEX  HISPAN_I  RACERPI2  R_MARITL  HYPEV  CHLEV  CHDEV  \
# 0        1       3    2        12         1         4      1      1      2
# 1        1       2    1        12         1         7      2      2      2
# 2        1       2    1        12         1         1      2      2      2
# 3        1       2    2        12         1         5      2      2      2
# 4        1       3    1         0         1         1      2      2      2
#
#    EPHEV  ...  AHCHYR  ASRGYR  AMDLONGR  AEXCHNG  ASICPUSE  ASISIM  ASISIF  \
# 0      2  ...       2       2         2      NaN         4     NaN     2.0
# 1      2  ...       2       2         2      2.0         4     2.0     NaN
# 2      2  ...       2       2         1      2.0         3     2.0     NaN
# 3      2  ...       2       2         1      NaN         4     NaN     2.0
# 4      2  ...       2       2         2      2.0         4     2.0     NaN
#
#    ASISLPFL  MBO_SPR1  AFLHCA17
# 0         0         2       NaN
# 1         6         2       NaN
# 2         7         2       2.0
# 3         0         1       NaN
# 4         0         1       NaN
#
# [5 rows x 40 columns]

# %%
filtered_data_2017 = filtered_data_2017.rename(columns = {"AFLHCA17" : "Suffering from Dep/Anx", "REGION" : "Geographic Region", "SEX" : "SEX",
                                                          "HISPAN_I" : "Hispanic Origin",
                                                          "RACERPI2" : "Race", "R_MARITL" : "Marital Status",
                                                          "HYPEV" : "Hypertension", "CHLEV" : "Cholesterol",
                                                          "CHDEV" : "Coronary Heart Disease", "EPHEV" : "emphysema",
                                                          "AASMEV" : "Asthma", "CANEV" : "Cancer",
                                                          "DIBEV1" : "Diabetes", "DIBTYPE" : "Diabetes Type",
                                                          "EPILEP1" : "Epilepsy", "ARTH1" : "Arthritis",
                                                          "HRAIDNOW" : "Usin a Hearing Aid",
                                                          "AVISION" : "Trouble seeing W/Glasses/Lenses",
                                                          "AHSTATYR" : "Health Status (Past 12m)",
                                                          "PAINLMT" : "Pain Severity (Past 6m)",
                                                          "FLWALK" : "Mobility/Ability to Walk Unaided",
                                                          "ALCHRONR" : "Overall Functional Limitation",
                                                          "SMKSTAT2" : "Smoking Status",
                                                          "MODFREQW" : "Moderate Activity/W",
                                                          "ALCSTAT" : "Alcohol Drinking Status",
                                                          "AHCPLROU" : "Usual Place for Routine/Preventive Care",
                                                          "AWORPAY" : "Medical Bills Pay Worry",
                                                          "ADNLONG2" : "Time Since Dentist's Last Visit",
                                                          "AHCSYR1" : "Seen/Talked With Mental Specialist (Past 12m)",
                                                          "AHERNOY2" : "ER/ED Freq. (Past 12m)",
                                                          "AHCHYR" : "Home Care Received (Past 12m)",
                                                          "ASRGYR" : "Surgery/Surgical Procedures (Past 12m)",
                                                          "AMDLONGR" : "Time Since Last Seen/Talked to a Health Pro",
                                                          "AEXCHNG" : "Looked into Buying Ins. through Healthcare.gov/Health Ins. MP",
                                                          "ASICPUSE" : "Computer Use Freq.", "ASISIM" : "Sexual Orientation (M)",
                                                          "ASISIF" : "Sexual Orientation (F)",
                                                          "ASISLPFL" : "Difficutly Falling Asleep (Past W)",
                                                          "MBO_SPR1" : "Used Spiritual Meditation (Past 12m)",
                                                          "AWEBUSE" : "Internet use"
        })
filtered_data_2017
# Out:
#        Internet use  Geographic Region  SEX  Hispanic Origin  Race  \
# 0                 1                  3    2               12     1
# 1                 1                  2    1               12     1
# 2                 1                  2    1               12     1
# 3                 1                  2    2               12     1
# 4                 1                  3    1                0     1
# ...             ...                ...  ...              ...   ...
# 26737             1                  4    2               12     1
# 26738             1                  3    2               12     1
# 26739             1                  3    2               12     2
# 26740             1                  1    1               12     1
# 26741             1                  3    2               12     1
#
#        Marital Status  Hypertension  Cholesterol  Coronary Heart Disease  \
# 0                   4             1            1                       2
# 1                   7             2            2                       2
# 2                   1             2            2                       2
# 3                   5             2            2                       2
# 4                   1             2            2                       2
# ...               ...           ...          ...                     ...
# 26737               1             2            1                       2
# 26738               4             1            2                       2
# 26739               1             1            1                       2
# 26740               1             1            1                       2
# 26741               1             2            2                       2
#
#        emphysema  ...  Home Care Received (Past 12m)  \
# 0              2  ...                              2
# 1              2  ...                              2
# 2              2  ...                              2
# 3              2  ...                              2
# 4              2  ...                              2
# ...          ...  ...                            ...
# 26737          2  ...                              2
# 26738          2  ...                              2
# 26739          2  ...                              2
# 26740          2  ...                              2
# 26741          2  ...                              2
#
#        Surgery/Surgical Procedures (Past 12m)  \
# 0                                           2
# 1                                           2
# 2                                           2
# 3                                           2
# 4                                           2
# ...                                       ...
# 26737                                       2
# 26738                                       2
# 26739                                       2
# 26740                                       2
# 26741                                       2
#
#        Time Since Last Seen/Talked to a Health Pro  \
# 0                                                2
# 1                                                2
# 2                                                1
# 3                                                1
# 4                                                2
# ...                                            ...
# 26737                                            1
# 26738                                            1
# 26739                                            1
# 26740                                            1
# 26741                                            1
#
#        Looked into Buying Ins. through Healthcare.gov/Health Ins. MP  \
# 0                                                    NaN
# 1                                                    2.0
# 2                                                    2.0
# 3                                                    NaN
# 4                                                    2.0
# ...                                                  ...
# 26737                                                NaN
# 26738                                                NaN
# 26739                                                NaN
# 26740                                                NaN
# 26741                                                NaN
#
#        Computer Use Freq.  Sexual Orientation (M)  Sexual Orientation (F)  \
# 0                       4                     NaN                     2.0
# 1                       4                     2.0                     NaN
# 2                       3                     2.0                     NaN
# 3                       4                     NaN                     2.0
# 4                       4                     2.0                     NaN
# ...                   ...                     ...                     ...
# 26737                   4                     NaN                     2.0
# 26738                   4                     NaN                     2.0
# 26739                   2                     NaN                     2.0
# 26740                   4                     2.0                     NaN
# 26741                   4                     NaN                     2.0
#
#        Difficutly Falling Asleep (Past W)  \
# 0                                       0
# 1                                       6
# 2                                       7
# 3                                       0
# 4                                       0
# ...                                   ...
# 26737                                   1
# 26738                                   2
# 26739                                   0
# 26740                                   3
# 26741                                   0
#
#        Used Spiritual Meditation (Past 12m)  Suffering from Dep/Anx
# 0                                         2                     NaN
# 1                                         2                     NaN
# 2                                         2                     2.0
# 3                                         1                     NaN
# 4                                         1                     NaN
# ...                                     ...                     ...
# 26737                                     2                     2.0
# 26738                                     2                     2.0
# 26739                                     2                     NaN
# 26740                                     2                     NaN
# 26741                                     1                     2.0
#
# [26742 rows x 40 columns]

# %%
# Renaming the dataframe
df_17 = filtered_data_2017
corr = df_17.corr()

# %%
# plot a heat matrix
ax = sns.heatmap(corr,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 200, sep=1, n=100, l=50),
    square=True,
    xticklabels=True,
    yticklabels=True)

ax.set_yticklabels(ax.get_yticklabels(),fontsize=5);

ax.set_xticklabels(
    ax.get_xticklabels(),
    fontsize=5,
    horizontalalignment='right'
  
);

# Save image
plt.savefig("resources/Fig1.png")

# %%
#Create Bar Charts Comparing the Association between Depression and each of these Factors: Hypertension, Arthritis and Overall Functional Limitations
dep_df = filtered_data_2017[["Suffering from Dep/Anx","Hypertension","Arthritis","Overall Functional Limitation"]].dropna()

#get just yes and no's
dep_df = dep_df.loc[ filtered_data_2017["Suffering from Dep/Anx"].isin([1,2])
                   & filtered_data_2017["Hypertension"].isin([1,2])
                   & filtered_data_2017["Arthritis"].isin([1,2])
                   & filtered_data_2017["Overall Functional Limitation"].isin([1,2]), :]

dep_df.groupby("Suffering from Dep/Anx").mean().plot.bar(figsize =(8,6), ylim=(1,2))
plt.title("Hypertension, Arthritis and Functional Status are Significantly Associated with Depression/Anxiety")
# Out:
# Text(0.5, 1.0, 'Hypertension, Arthritis and Functional Status are Significantly Associated with Depression/Anxiety')

# %%
#Calculate Depression / Hypertension Chi Square
def calcDepressionHypertensionChiSquare(column, indexList):
    
    dep_y_hyp = filtered_data_2017.loc[filtered_data_2017["Difficulty with Daily Activity due to Dep/Anx"]==1][column].value_counts()
    dep_n_hyp = filtered_data_2017.loc[filtered_data_2017["Difficulty with Daily Activity due to Dep/Anx"]==2][column].value_counts()
    
    
    dep_y_hyp = dep_y_hyp.reset_index()
    dep_n_hyp = dep_n_hyp.reset_index()

    dep_y_hyp = dep_y_hyp.loc[dep_y_hyp["index"].isin(indexList),:]
    dep_n_hyp = dep_n_hyp.loc[dep_n_hyp["index"].isin(indexList),:]
    
    dep_y_hyp["Depressed"] = "Yes"
    dep_n_hyp["Depressed"] = "No"
    
    dep_hyp_counts_df = pd.concat([dep_n_hyp,dep_y_hyp])
    

    dep_hyp_counts_df["Expected"] = dep_hyp_counts_df[column].mean()
    
    print(dep_hyp_counts_df)
    
    critical_value = st.chi2.ppf(q = 0.95, df = len(dep_hyp_counts_df["Expected"])-1)
    
    chiSquare = st.chisquare(dep_hyp_counts_df[column],dep_hyp_counts_df["Expected"])
    
    print(chiSquare)
    
calcDepressionHypertensionChiSquare("Hypertension", [1,2])
# Out:
#    index  Hypertension Depressed  Expected
# 0      1          5605        No   2773.25
# 1      2          4738        No   2773.25
# 0      2           409       Yes   2773.25
# 1      1           341       Yes   2773.25
# Power_divergenceResult(statistic=8432.189218426034, pvalue=0.0)

# %%
#Calculate Depression / Arthritis Chi Square
def calcDepressionArthritisChiSquare(column, indexList):
    
    dep_y_hyp = filtered_data_2017.loc[filtered_data_2017["Difficulty with Daily Activity due to Dep/Anx"]==1][column].value_counts()
    dep_n_hyp = filtered_data_2017.loc[filtered_data_2017["Difficulty with Daily Activity due to Dep/Anx"]==2][column].value_counts()
    
    
    dep_y_hyp = dep_y_hyp.reset_index()
    dep_n_hyp = dep_n_hyp.reset_index()

    dep_y_hyp = dep_y_hyp.loc[dep_y_hyp["index"].isin(indexList),:]
    dep_n_hyp = dep_n_hyp.loc[dep_n_hyp["index"].isin(indexList),:]
    
    dep_y_hyp["Depressed"] = "Yes"
    dep_n_hyp["Depressed"] = "No"
    
    dep_hyp_counts_df = pd.concat([dep_n_hyp,dep_y_hyp])
    

    dep_hyp_counts_df["Expected"] = dep_hyp_counts_df[column].mean()
    
    print(dep_hyp_counts_df)
    
    critical_value = st.chi2.ppf(q = 0.95, df = len(dep_hyp_counts_df["Expected"])-1)
    
    chiSquare = st.chisquare(dep_hyp_counts_df[column],dep_hyp_counts_df["Expected"])
    
    print(chiSquare)
    
calcDepressionArthritisChiSquare("Arthritis", [1,2])
# Out:
#    index  Arthritis Depressed  Expected
# 0      1       5411        No    2770.5
# 1      2       4918        No    2770.5
# 0      1        379       Yes    2770.5
# 1      2        374       Yes    2770.5
# Power_divergenceResult(statistic=8318.52770258076, pvalue=0.0)

# %%
#Calculate Depression / Arthritis Chi Square
def calcDepressionHypertensionChiSquare(column, indexList):
    
    dep_y_hyp = filtered_data_2017.loc[filtered_data_2017["Difficulty with Daily Activity due to Dep/Anx"]==1][column].value_counts()
    dep_n_hyp = filtered_data_2017.loc[filtered_data_2017["Difficulty with Daily Activity due to Dep/Anx"]==2][column].value_counts()
    
    
    dep_y_hyp = dep_y_hyp.reset_index()
    dep_n_hyp = dep_n_hyp.reset_index()

    dep_y_hyp = dep_y_hyp.loc[dep_y_hyp["index"].isin(indexList),:]
    dep_n_hyp = dep_n_hyp.loc[dep_n_hyp["index"].isin(indexList),:]
    
    dep_y_hyp["Depressed"] = "Yes"
    dep_n_hyp["Depressed"] = "No"
    
    dep_hyp_counts_df = pd.concat([dep_n_hyp,dep_y_hyp])
    

    dep_hyp_counts_df["Expected"] = dep_hyp_counts_df[column].mean()
    
    print(dep_hyp_counts_df)
    
    critical_value = st.chi2.ppf(q = 0.95, df = len(dep_hyp_counts_df["Expected"])-1)
    
    chiSquare = st.chisquare(dep_hyp_counts_df[column],dep_hyp_counts_df["Expected"])
    
    print(chiSquare)
    
calcDepressionHypertensionChiSquare("Arthritis", [1,2])
# Out:
#    index  Arthritis Depressed  Expected
# 0      1       5411        No    2770.5
# 1      2       4918        No    2770.5
# 0      1        379       Yes    2770.5
# 1      2        374       Yes    2770.5
# Power_divergenceResult(statistic=8318.52770258076, pvalue=0.0)

# %%
#Calculate Depression / Overall Functional Limitation Chi Square
def calcDepressionFunctSquare(column, indexList):
    
    dep_y_hyp = filtered_data_2017.loc[filtered_data_2017["Difficulty with Daily Activity due to Dep/Anx"]==1][column].value_counts()
    dep_n_hyp = filtered_data_2017.loc[filtered_data_2017["Difficulty with Daily Activity due to Dep/Anx"]==2][column].value_counts()
    
    
    dep_y_hyp = dep_y_hyp.reset_index()
    dep_n_hyp = dep_n_hyp.reset_index()

    dep_y_hyp = dep_y_hyp.loc[dep_y_hyp["index"].isin(indexList),:]
    dep_n_hyp = dep_n_hyp.loc[dep_n_hyp["index"].isin(indexList),:]
    
    dep_y_hyp["Depressed"] = "Yes"
    dep_n_hyp["Depressed"] = "No"
    
    dep_hyp_counts_df = pd.concat([dep_n_hyp,dep_y_hyp])
    

    dep_hyp_counts_df["Expected"] = dep_hyp_counts_df[column].mean()
    
    print(dep_hyp_counts_df)
    
    critical_value = st.chi2.ppf(q = 0.95, df = len(dep_hyp_counts_df["Expected"])-1)
    
    chiSquare = st.chisquare(dep_hyp_counts_df[column],dep_hyp_counts_df["Expected"])
    
    print(chiSquare)
    
calcDepressionFunctSquare("Overall Functional Limitation", [1,2])
# Out:
#    index  Overall Functional Limitation Depressed  Expected
# 0      1                          10081        No   2757.25
# 1      2                            202        No   2757.25
# 0      1                            741       Yes   2757.25
# 2      2                              5       Yes   2757.25
# Power_divergenceResult(statistic=26042.890833257778, pvalue=0.0)
